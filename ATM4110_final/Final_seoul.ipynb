# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import netCDF4
import glob

# %%
datapath = '/home/e2018136018/notebook/data2/'

# %%
f1 = netCDF4.Dataset(datapath + 'ei.moda.an.sfc.regn128sc.2000010100.nc')
f1.variables
# Out:
# {'CVL_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 CVL_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 27
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: (0 - 1)
#      long_name: Low vegetation cover
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'CVH_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 CVH_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 28
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: (0 - 1)
#      long_name: High vegetation cover
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'TVL_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 TVL_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 29
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: -
#      long_name: Type of low vegetation
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'TVH_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 TVH_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 30
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: -
#      long_name: Type of high vegetation
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'CI_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 CI_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 31
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: (0 - 1)
#      long_name: Sea-ice cover
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'ASN_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 ASN_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 32
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: (0 - 1)
#      long_name: Snow albedo
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'RSN_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 RSN_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 33
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: kg m**-3
#      long_name: Snow density
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'SSTK_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 SSTK_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 34
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: K
#      long_name: Sea surface temperature
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'ISTL1_GDS4_DBLY_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 ISTL1_GDS4_DBLY_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      level: [0 7]
#      parameter_number: 35
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 112
#      _FillValue: 1e+20
#      units: K
#      long_name: Ice surface temperature layer 1
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'ISTL2_GDS4_DBLY_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 ISTL2_GDS4_DBLY_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      level: [ 7 28]
#      parameter_number: 36
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 112
#      _FillValue: 1e+20
#      units: K
#      long_name: Ice surface temperature layer 2
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'ISTL3_GDS4_DBLY_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 ISTL3_GDS4_DBLY_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      level: [ 28 100]
#      parameter_number: 37
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 112
#      _FillValue: 1e+20
#      units: K
#      long_name: Ice surface temperature layer 3
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'ISTL4_GDS4_DBLY_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 ISTL4_GDS4_DBLY_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      level: [100 255]
#      parameter_number: 38
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 112
#      _FillValue: 1e+20
#      units: K
#      long_name: Ice surface temperature layer 4
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'SWVL1_GDS4_DBLY_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 SWVL1_GDS4_DBLY_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      level: [0 7]
#      parameter_number: 39
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 112
#      _FillValue: 1e+20
#      units: m**3 m**-3
#      long_name: Volumetric soil water layer 1
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'SWVL2_GDS4_DBLY_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 SWVL2_GDS4_DBLY_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      level: [ 7 28]
#      parameter_number: 40
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 112
#      _FillValue: 1e+20
#      units: m**3 m**-3
#      long_name: Volumetric soil water layer 2
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'SWVL3_GDS4_DBLY_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 SWVL3_GDS4_DBLY_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      level: [ 28 100]
#      parameter_number: 41
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 112
#      _FillValue: 1e+20
#      units: m**3 m**-3
#      long_name: Volumetric soil water layer 3
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'SWVL4_GDS4_DBLY_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 SWVL4_GDS4_DBLY_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      level: [100 255]
#      parameter_number: 42
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 112
#      _FillValue: 1e+20
#      units: m**3 m**-3
#      long_name: Volumetric soil water layer 4
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'SDFOR_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 SDFOR_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 74
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: m
#      long_name: Standard deviation of filtered subgrid orography
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'Z_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 Z_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 129
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: m**2 s**-2
#      long_name: Geopotential
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'SP_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 SP_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 134
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: Pa
#      long_name: Surface pressure
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'TCW_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 TCW_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 136
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: kg m**-2
#      long_name: Total column water
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'TCWV_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 TCWV_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 137
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: kg m**-2
#      long_name: Total column water vapour
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'STL1_GDS4_DBLY_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 STL1_GDS4_DBLY_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      level: [0 7]
#      parameter_number: 139
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 112
#      _FillValue: 1e+20
#      units: K
#      long_name: Soil temperature level 1
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'SD_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 SD_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 141
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: m of water equivalent
#      long_name: Snow depth
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'CHNK_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 CHNK_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 148
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: -
#      long_name: Charnock
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'MSL_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 MSL_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 151
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: Pa
#      long_name: Mean sea level pressure
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'SDOR_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 SDOR_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 160
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: -
#      long_name: Standard deviation of orography
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'ISOR_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 ISOR_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 161
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: -
#      long_name: Anisotropy of sub-gridscale orography
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'ANOR_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 ANOR_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 162
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: rad
#      long_name: Angle of sub-gridscale orography
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'SLOR_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 SLOR_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 163
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: -
#      long_name: Slope of sub-gridscale orography
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'TCC_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 TCC_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 164
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: (0 - 1)
#      long_name: Total cloud cover
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  '10U_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 10U_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 165
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: m s**-1
#      long_name: 10 metre U wind component
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  '10V_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 10V_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 166
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: m s**-1
#      long_name: 10 metre V wind component
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  '2T_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 2T_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 167
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: K
#      long_name: 2 metre temperature
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  '2D_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 2D_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 168
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: K
#      long_name: 2 metre dewpoint temperature
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'STL2_GDS4_DBLY_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 STL2_GDS4_DBLY_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      level: [ 7 28]
#      parameter_number: 170
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 112
#      _FillValue: 1e+20
#      units: K
#      long_name: Soil temperature level 2
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'LSM_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 LSM_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 172
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: (0 - 1)
#      long_name: Land-sea mask
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'SR_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 SR_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 173
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: m
#      long_name: Surface roughness
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'AL_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 AL_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 174
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: (0 - 1)
#      long_name: Albedo
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'STL3_GDS4_DBLY_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 STL3_GDS4_DBLY_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      level: [ 28 100]
#      parameter_number: 183
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 112
#      _FillValue: 1e+20
#      units: K
#      long_name: Soil temperature level 3
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'LCC_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 LCC_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 186
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: (0 - 1)
#      long_name: Low cloud cover
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'MCC_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 MCC_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 187
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: (0 - 1)
#      long_name: Medium cloud cover
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'HCC_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 HCC_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 188
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: (0 - 1)
#      long_name: High cloud cover
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'SRC_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 SRC_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 198
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: m of water
#      long_name: Skin reservoir content
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'TCO3_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 TCO3_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 206
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: kg m**-2
#      long_name: Total column ozone
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  '10SI_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 10SI_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 207
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: m s**-1
#      long_name: 10 metre wind speed
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'LSRH_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 LSRH_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 234
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: -
#      long_name: Logarithm of surface roughness length for heat
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'SKT_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 SKT_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 235
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: K
#      long_name: Skin temperature
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'STL4_GDS4_DBLY_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 STL4_GDS4_DBLY_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      level: [100 255]
#      parameter_number: 236
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 112
#      _FillValue: 1e+20
#      units: K
#      long_name: Soil temperature level 4
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'TSN_GDS4_SFC_S123': <class 'netCDF4._netCDF4.Variable'>
#  float32 TSN_GDS4_SFC_S123(g4_lat_0, g4_lon_1)
#      N: 124
#      statistical_process_duration: instantaneous (beginning at reference time at intervals of 6 hours)
#      statistical_process_descriptor: average of N uninitialized analyses
#      initial_time: 01/01/2000 (00:00)
#      forecast_time_units: hours
#      forecast_time: 0
#      parameter_number: 238
#      parameter_table_version: 128
#      gds_grid_type: 4
#      level_indicator: 1
#      _FillValue: 1e+20
#      units: K
#      long_name: Temperature of snow layer
#      center: European Center for Medium-Range Weather Forecasts (RSMC)
#  unlimited dimensions:
#  current shape = (256, 512)
#  filling on,
#  'g4_lat_0': <class 'netCDF4._netCDF4.Variable'>
#  float32 g4_lat_0(g4_lat_0)
#      La1: 89.463
#      Lo1: 0.0
#      La2: -89.463
#      Lo2: 359.297
#      Di: 0.70312524
#      N: 128.0
#      units: degrees_north
#      GridType: Gaussian Latitude/Longitude Grid
#      long_name: latitude
#  unlimited dimensions:
#  current shape = (256,)
#  filling on, default _FillValue of 9.969209968386869e+36 used,
#  'g4_lon_1': <class 'netCDF4._netCDF4.Variable'>
#  float32 g4_lon_1(g4_lon_1)
#      La1: 89.463
#      Lo1: 0.0
#      La2: -89.463
#      Lo2: 359.297
#      Di: 0.70312524
#      N: 128.0
#      units: degrees_east
#      GridType: Gaussian Latitude/Longitude Grid
#      long_name: longitude
#  unlimited dimensions:
#  current shape = (512,)
#  filling on, default _FillValue of 9.969209968386869e+36 used}

# %%
f1.variables.keys()
# Out:
# dict_keys(['CVL_GDS4_SFC_S123', 'CVH_GDS4_SFC_S123', 'TVL_GDS4_SFC_S123', 'TVH_GDS4_SFC_S123', 'CI_GDS4_SFC_S123', 'ASN_GDS4_SFC_S123', 'RSN_GDS4_SFC_S123', 'SSTK_GDS4_SFC_S123', 'ISTL1_GDS4_DBLY_S123', 'ISTL2_GDS4_DBLY_S123', 'ISTL3_GDS4_DBLY_S123', 'ISTL4_GDS4_DBLY_S123', 'SWVL1_GDS4_DBLY_S123', 'SWVL2_GDS4_DBLY_S123', 'SWVL3_GDS4_DBLY_S123', 'SWVL4_GDS4_DBLY_S123', 'SDFOR_GDS4_SFC_S123', 'Z_GDS4_SFC_S123', 'SP_GDS4_SFC_S123', 'TCW_GDS4_SFC_S123', 'TCWV_GDS4_SFC_S123', 'STL1_GDS4_DBLY_S123', 'SD_GDS4_SFC_S123', 'CHNK_GDS4_SFC_S123', 'MSL_GDS4_SFC_S123', 'SDOR_GDS4_SFC_S123', 'ISOR_GDS4_SFC_S123', 'ANOR_GDS4_SFC_S123', 'SLOR_GDS4_SFC_S123', 'TCC_GDS4_SFC_S123', '10U_GDS4_SFC_S123', '10V_GDS4_SFC_S123', '2T_GDS4_SFC_S123', '2D_GDS4_SFC_S123', 'STL2_GDS4_DBLY_S123', 'LSM_GDS4_SFC_S123', 'SR_GDS4_SFC_S123', 'AL_GDS4_SFC_S123', 'STL3_GDS4_DBLY_S123', 'LCC_GDS4_SFC_S123', 'MCC_GDS4_SFC_S123', 'HCC_GDS4_SFC_S123', 'SRC_GDS4_SFC_S123', 'TCO3_GDS4_SFC_S123', '10SI_GDS4_SFC_S123', 'LSRH_GDS4_SFC_S123', 'SKT_GDS4_SFC_S123', 'STL4_GDS4_DBLY_S123', 'TSN_GDS4_SFC_S123', 'g4_lat_0', 'g4_lon_1'])

# %%
lats = f1.variables['g4_lat_0'][:]
lons = f1.variables['g4_lon_1'][:]

seoul_lat = np.abs(lats - 37.57).argmin() #서울에서 가장 가까운 지점 찾기
seoul_lon = np.abs(lons - 126.98).argmin()

# %%
files = glob.glob(datapath+'*.nc') #nc 파일 다 불러오기
dataset = np.zeros(len(files), dtype=np.float32)

# %%
idx = 0
for i in files:
    f_data = netCDF4.Dataset(i,'r')
    dataset[idx] = f_data.variables['2T_GDS4_SFC_S123'][seoul_lat,seoul_lon]
    idx += 1 #서울의 온도 데이터만 모으기

# %%
dataset.shape #모양 확인
# Out:
# (236,)

# %%
date = pd.date_range('20000101','20190801',freq='MS')
date #날짜자료 만들어줌
# Out:
# DatetimeIndex(['2000-01-01', '2000-02-01', '2000-03-01', '2000-04-01',
#                '2000-05-01', '2000-06-01', '2000-07-01', '2000-08-01',
#                '2000-09-01', '2000-10-01',
#                ...
#                '2018-11-01', '2018-12-01', '2019-01-01', '2019-02-01',
#                '2019-03-01', '2019-04-01', '2019-05-01', '2019-06-01',
#                '2019-07-01', '2019-08-01'],
#               dtype='datetime64[ns]', length=236, freq='MS')

# %%
Seoul = pd.DataFrame(data = dataset-273.15, index = date, columns=['Temperature(℃)'])
Seoul #날짜를 index로 data는 섭씨온도니까 273.15를 뺌
# Out:
#             Temperature(℃)
# 2000-01-01       -2.662231
# 2000-02-01       -2.249786
# 2000-03-01        5.050201
# 2000-04-01       10.810516
# 2000-05-01       16.761139
# ...                    ...
# 2019-04-01       11.474457
# 2019-05-01       18.838104
# 2019-06-01       21.747650
# 2019-07-01       25.059601
# 2019-08-01       25.845734
#
# [236 rows x 1 columns]

# %%
plt.figure(figsize=(12,8))
plt.plot(Seoul, marker='o')
plt.xlabel('Year', fontsize=12) ; plt.ylabel('Temperature(℃)', fontsize=12)
plt.title('Temperature in Seoul', fontsize=15)
plt.show()

# %%
Seoul.groupby(Seoul.index.month).mean()
#월평균 온도는 월로 묶고 평균
# Out:
#     Temperature(℃)
# 1        -3.302303
# 2        -0.424498
# 3         5.208481
# 4        11.831064
# 5        17.747883
# 6        22.147991
# 7        24.763754
# 8        25.239529
# 9        20.338251
# 10       13.705005
# 11        6.229293
# 12       -1.273004

# %%
plt.figure(figsize=(10,6))
plt.plot(Seoul.groupby(Seoul.index.month).mean(), marker='o')
plt.grid()
plt.xlabel('Month' ,fontsize=12) ; plt.ylabel('Temperature(℃)' ,fontsize=12)
plt.xticks(np.arange(1,13,1))
plt.title('Monthly average temperature in Seoul', fontsize=13)
plt.show()
